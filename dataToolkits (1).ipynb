# %% [markdown]
# 1  What is NumPy, and why is it widely used in Python ?
#
#    -->Numpy is a powerful library in python which is used for numeral and scientific computaion
#
# 2  How does broadcasting work in NumPy?
#     -->it is genrally used for element-wise operation on arrays of differnt shapes
#     when performing the elementary of operation on it it tries to stech the smaller array to bring to the shape of larger array then it  performs the operation
#
# 3 What is a Pandas DataFrame ?
#
#   -->data frame is a flexible conatiner that allows an easy manipulation and analysis of data
#
# 4  Explain the use of the groupby() method in Pandas?
#
#    -->It allows you to group your data based on one or more columns, and then apply aggregation functions (such as sum, mean, count, etc.) to each group.
#
# 5 Why is Seaborn preferred for statistical visualization?
#
#    -->Seaborn is preferred for statistical visualization in Python because it builds on top of Matplotlib and provides a high-level, easy-to-use interface for creating complex and informative visualizations with just a few lines of code
#
# 6  What are the differences between NumPy arrays and Python lists ?
#   --> python lists are a collection of same datatype or can be collection of different datatypes whereas numpy array are the collection of similar datatype elements
#
# 7 What is a heatmap, and when should it be used?
#    -->A heatmap is a data visualization technique that uses color gradients to represent values in a matrix, making patterns and relationships easily identifiable. It's commonly used for visualizing correlation matrices, missing data, and performance metrics like confusion matrices
#
# 8 What does the term “vectorized operation” mean in NumPy??
#
#   --> 'vectorized operation' in NumPy refers to performing element-wise operations on entire arrays or matrices
#
# 9 How does Matplotlib differ from Plotly?
#
#   --> Matplotlib is used for creating static visualaization whereas plottly use for creating interactive visulaization
#
# 10 What is the significance of hierarchical indexing in Pandas
#
# -->Hierarchical indexing in Pandas allows you to work with multi-level indices, enabling more complex data structures and easier data manipulation. It helps in organizing and accessing data in a hierarchical manner, which is especially useful for handling high-dimensional data in a 2D format (e.g., time series or multi-level categorical data
#
# 11 What is the role of Seaborn’s pairplot() function?
#
# -->The pairplot() function in Seaborn creates a grid of scatter plots to visualize pairwise relationships between multiple variables, along with histograms for individual variables. It's useful for exploring correlations and distributions in a dataset.
#
# 12 What is the purpose of the describe() function in Pandas?
#
#   -->it provide 5 point summary data that is min max 25percintile ,50percentile 75 percintile
#
# 13 Why is handling missing data important in Pandas?
#
# -->Handling missing data is crucial in Pandas to prevent errors during analysis and ensure accurate results. Techniques like imputation or removal help maintain data integrity and completeness.
#
# 14 What are the benefits of using Plotly for data visualization?
#
# -->Plotly provides interactive visualizations with features like zoom, tooltips, and easy embedding in web applications. It simplifies creating dynamic, engaging plots with minimal code.
#
# 15 How does NumPy handle multidimensional arrays?
#
#   -->NumPy uses ndarray (N-dimensional array) objects to efficiently handle multidimensional arrays. It supports vectorized operations and element-wise computations across dimensions, enabling high-performance data manipulation.
#
# 16 What is the role of Bokeh in data visualization?
#    -->Bokeh specializes in creating interactive, web-based visualizations.
#
# 17 Explain the difference between apply() and map() in Pandas.
#
#   --> apply() applies a function along a DataFrame’s axis (rows or columns), while map() is used to apply a function element-wise to a Series. apply() can be used on both rows and columns, whereas map() is Series-specific.
#
# 18 what are some advanced features of NumPy?
#
#   -->Advanced features of NumPy include broadcasting, advanced indexing, linear algebra functions, random number generation, and tools for performing Fourier transforms and statistical operations.
#
# 19 How does Pandas simplify time series analysis?
#
# -->Pandas simplifies time series analysis by providing powerful tools for handling date and time data, such as DatetimeIndex, resampling, and date-based indexing, making it easier to perform operations like rolling windows and shifting.
#
# 20 What is the role of a pivot table in Pandas?
#
#   -->A pivot table in Pandas allows you to reorganize and summarize data, aggregating it based on different levels of a categorical variable. It's useful for multi-dimensional data analysis and generating summary statistics.
#
# 21 Why is NumPy’s array slicing faster than Python’s list slicing?
#
#    -->NumPy’s array slicing is faster because it operates on contiguous memory blocks and leverages optimized C implementations, while Python’s lists require more overhead due to dynamic resizing and element-by-element access.
#
# 22 What are some common use cases for Seaborn?
#
# -->Seaborn is commonly used for statistical visualizations such as heatmaps, correlation matrices, categoric

# %%
from ast import Name
#How do you create a 2D NumPy array and calculate the sum of each row
import numpy as np

arr1=np.array([[1,2,3],[4,5,6]])
row_sum=np.sum(arr1,axis=1)
print(row_sum)

# Write a Pandas script to find the mean of a specific column in a DataFrame

import pandas as pd

df=pd.DataFrame(arr1)
df.rename(columns={0:'COL1' , 1:"COl2",} ,inplace=True)
specific_col=df['COL1'].mean()
print(specific_col)

#  Create a scatter plot using Matplotlib
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[2,3,4,5]

plt.scatter(x,y)
plt.show()

#How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap
import seaborn as sns
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True)
plt.show()

# Generate a bar plot using Plotly
import plotly.express as px
fig=px.bar(x,y)
fig.show()

#
some_values=[[1,2,3],[4,5,6],[7,8,9]]
df2=pd.DataFrame(some_values)
df2.rename(columns={0:'COL1' , 1:"COl2",2:"COL3"},inplace=True)
df2["sum of rows"]=df2.sum(axis=1)
print(df2)

# Write a program to perform element-wise multiplication of two NumPy arrays
arr1=np.array([1,2,3])
arr2=np.array([4,5,6])
result=arr1*arr2
print(result)


# Create a line plot with multiple lines using Matplotlib
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[2,3,4,5]
a=[4,3,5,7]
plt.plot(x,y , label='line1')
plt.plot(a,x , label='line2')
plt.legend()
plt.show()

#

threshold_value=5
filtered_df=df2[df2['sum of rows']>threshold_value]
print(filtered_df)

#Create a histogram using Seaborn to visualize a distribution
sns.histplot(df2['sum of rows'])
plt.show()

# Perform matrix multiplication using NumPy
matrix1=np.array([[1,2],[3,4]])
matrix2=np.array([[5,6],[7,8]])
result=np.dot(matrix1,matrix2)
print(result)

#Use Pandas to load a CSV file and display its first 5 rows
# df3=pd.read_csv("data.csv") since i dont have any csv file in am commoning out it
# print(df3.head(5))

#Create a 3D scatter plot using Plotly.
import plotly.graph_objects as go
import numpy as np
import plotly.graph_objects as go
import numpy as np

# Generate random data for the 3D scatter plot
np.random.seed(42)
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

# Create a 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers'

)])

# Update the layout

# Show the plot
fig.show()
# Out:
# [ 6 15]
# 2.5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
